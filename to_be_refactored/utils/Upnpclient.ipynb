# %%
import upnpclient
import xml.etree.ElementTree as ET

# %%
device = upnpclient.discover()
device
# Out:
# [<Device 'G81-69497D'>]

# %%
print(device[0].udn)
print(device[0].friendly_name)
# Out:
# uuid:4D454930-0100-1000-8000-1848CA69497D
# G81-69497D

# %%
service = device[0]

a = service.ContentDirectory.Browse(ObjectID=1, BrowseFlag='BrowseDirectChildren', Filter="*", StartingIndex=1, RequestedCount=200, SortCriteria="")
# Out:
# {}

# %%
a = '<DIDL-Lite xmlns="urn:schemas-upnp-org:metadata-1-0/DIDL-Lite/" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:upnp="urn:schemas-upnp-org:metadata-1-0/upnp/"><item id="1000092" parentID="0" restricted="0"><dc:title>100-0092</dc:title><upnp:writeStatus>WRITABLE</upnp:writeStatus><upnp:class name="imageItem">object.item.imageItem</upnp:class><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_LRG;DLNA.ORG_OP=01;DLNA.ORG_CI=0;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_ORG" size="3284480">http://192.168.54.1:50001/DO1000092.JPG</res><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_TN;DLNA.ORG_OP=01;DLNA.ORG_CI=1;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_TN" size="5000">http://192.168.54.1:50001/DT1000092.JPG</res><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_SM;DLNA.ORG_OP=01;DLNA.ORG_CI=1;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_LRGTN" size="100000">http://192.168.54.1:50001/DS1000092.JPG</res></item><item id="1000093" parentID="0" restricted="0"><dc:title>100-0093</dc:title><upnp:writeStatus>WRITABLE</upnp:writeStatus><upnp:class name="imageItem">object.item.imageItem</upnp:class><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_LRG;DLNA.ORG_OP=01;DLNA.ORG_CI=0;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_ORG" size="3289088">http://192.168.54.1:50001/DO1000093.JPG</res><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_TN;DLNA.ORG_OP=01;DLNA.ORG_CI=1;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_TN" size="5000">http://192.168.54.1:50001/DT1000093.JPG</res><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_SM;DLNA.ORG_OP=01;DLNA.ORG_CI=1;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_LRGTN" size="100000">http://192.168.54.1:50001/DS1000093.JPG</res></item><item id="1000102" parentID="0" restricted="0"><dc:title>100-0102</dc:title><upnp:writeStatus>WRITABLE</upnp:writeStatus><upnp:class name="imageItem">object.item.imageItem</upnp:class><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_LRG;DLNA.ORG_OP=01;DLNA.ORG_CI=0;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_ORG" size="4064256">http://192.168.54.1:50001/DO1000102.JPG</res><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_TN;DLNA.ORG_OP=01;DLNA.ORG_CI=1;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_TN" size="5000">http://192.168.54.1:50001/DT1000102.JPG</res><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_SM;DLNA.ORG_OP=01;DLNA.ORG_CI=1;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_LRGTN" size="100000">http://192.168.54.1:50001/DS1000102.JPG</res></item><item id="1000117" parentID="0" restricted="0"><dc:title>100-0117</dc:title><upnp:writeStatus>WRITABLE</upnp:writeStatus><upnp:class name="imageItem">object.item.imageItem</upnp:class><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_LRG;DLNA.ORG_OP=01;DLNA.ORG_CI=0;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_ORG" size="3919872">http://192.168.54.1:50001/DO1000117.JPG</res><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_TN;DLNA.ORG_OP=01;DLNA.ORG_CI=1;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_TN" size="5000">http://192.168.54.1:50001/DT1000117.JPG</res><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_SM;DLNA.ORG_OP=01;DLNA.ORG_CI=1;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_LRGTN" size="100000">http://192.168.54.1:50001/DS1000117.JPG</res></item><item id="1000156" parentID="0" restricted="0"><dc:title>100-0156</dc:title><upnp:writeStatus>WRITABLE</upnp:writeStatus><upnp:class name="imageItem">object.item.imageItem</upnp:class><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_LRG;DLNA.ORG_OP=01;DLNA.ORG_CI=0;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_ORG" size="4928000">http://192.168.54.1:50001/DO1000156.JPG</res><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_TN;DLNA.ORG_OP=01;DLNA.ORG_CI=1;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_TN" size="5000">http://192.168.54.1:50001/DT1000156.JPG</res><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_SM;DLNA.ORG_OP=01;DLNA.ORG_CI=1;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_LRGTN" size="100000">http://192.168.54.1:50001/DS1000156.JPG</res></item><item id="1000157" parentID="0" restricted="0"><dc:title>100-0157</dc:title><upnp:writeStatus>WRITABLE</upnp:writeStatus><upnp:class name="imageItem">object.item.imageItem</upnp:class><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_LRG;DLNA.ORG_OP=01;DLNA.ORG_CI=0;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_ORG" size="4507648">http://192.168.54.1:50001/DO1000157.JPG</res><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_TN;DLNA.ORG_OP=01;DLNA.ORG_CI=1;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_TN" size="5000">http://192.168.54.1:50001/DT1000157.JPG</res><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_SM;DLNA.ORG_OP=01;DLNA.ORG_CI=1;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_LRGTN" size="100000">http://192.168.54.1:50001/DS1000157.JPG</res></item><item id="1000158" parentID="0" restricted="0"><dc:title>100-0158</dc:title><upnp:writeStatus>WRITABLE</upnp:writeStatus><upnp:class name="imageItem">object.item.imageItem</upnp:class><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_LRG;DLNA.ORG_OP=01;DLNA.ORG_CI=0;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_ORG" size="4227072">http://192.168.54.1:50001/DO1000158.JPG</res><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_TN;DLNA.ORG_OP=01;DLNA.ORG_CI=1;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_TN" size="5000">http://192.168.54.1:50001/DT1000158.JPG</res><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_SM;DLNA.ORG_OP=01;DLNA.ORG_CI=1;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_LRGTN" size="100000">http://192.168.54.1:50001/DS1000158.JPG</res></item><item id="1000162" parentID="0" restricted="0"><dc:title>100-0162</dc:title><upnp:writeStatus>WRITABLE</upnp:writeStatus><upnp:class name="imageItem">object.item.imageItem</upnp:class><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_LRG;DLNA.ORG_OP=01;DLNA.ORG_CI=0;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_ORG" size="4488704">http://192.168.54.1:50001/DO1000162.JPG</res><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_TN;DLNA.ORG_OP=01;DLNA.ORG_CI=1;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_TN" size="5000">http://192.168.54.1:50001/DT1000162.JPG</res><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_SM;DLNA.ORG_OP=01;DLNA.ORG_CI=1;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_LRGTN" size="100000">http://192.168.54.1:50001/DS1000162.JPG</res></item><item id="1000170" parentID="0" restricted="0"><dc:title>100-0170</dc:title><upnp:writeStatus>WRITABLE</upnp:writeStatus><upnp:class name="imageItem">object.item.imageItem</upnp:class><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_LRG;DLNA.ORG_OP=01;DLNA.ORG_CI=0;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_ORG" size="4182016">http://192.168.54.1:50001/DO1000170.JPG</res><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_TN;DLNA.ORG_OP=01;DLNA.ORG_CI=1;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_TN" size="5000">http://192.168.54.1:50001/DT1000170.JPG</res><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_SM;DLNA.ORG_OP=01;DLNA.ORG_CI=1;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_LRGTN" size="100000">http://192.168.54.1:50001/DS1000170.JPG</res></item><item id="1000171" parentID="0" restricted="0"><dc:title>100-0171</dc:title><upnp:writeStatus>WRITABLE</upnp:writeStatus><upnp:class name="imageItem">object.item.imageItem</upnp:class><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_LRG;DLNA.ORG_OP=01;DLNA.ORG_CI=0;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_ORG" size="7877632">http://192.168.54.1:50001/DO1000171.JPG</res><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_TN;DLNA.ORG_OP=01;DLNA.ORG_CI=1;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_TN" size="5000">http://192.168.54.1:50001/DT1000171.JPG</res><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_SM;DLNA.ORG_OP=01;DLNA.ORG_CI=1;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_LRGTN" size="100000">http://192.168.54.1:50001/DS1000171.JPG</res></item><item id="1000172" parentID="0" restricted="0"><dc:title>100-0172</dc:title><upnp:writeStatus>WRITABLE</upnp:writeStatus><upnp:class name="imageItem">object.item.imageItem</upnp:class><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_LRG;DLNA.ORG_OP=01;DLNA.ORG_CI=0;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_ORG" size="7725056">http://192.168.54.1:50001/DO1000172.JPG</res><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_TN;DLNA.ORG_OP=01;DLNA.ORG_CI=1;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_TN" size="5000">http://192.168.54.1:50001/DT1000172.JPG</res><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_SM;DLNA.ORG_OP=01;DLNA.ORG_CI=1;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_LRGTN" size="100000">http://192.168.54.1:50001/DS1000172.JPG</res></item><item id="1000184" parentID="0" restricted="0"><dc:title>100-0184</dc:title><upnp:writeStatus>WRITABLE</upnp:writeStatus><upnp:class name="imageItem">object.item.imageItem</upnp:class><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_LRG;DLNA.ORG_OP=01;DLNA.ORG_CI=0;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_ORG" size="4195840">http://192.168.54.1:50001/DO1000184.JPG</res><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_TN;DLNA.ORG_OP=01;DLNA.ORG_CI=1;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_TN" size="5000">http://192.168.54.1:50001/DT1000184.JPG</res><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_SM;DLNA.ORG_OP=01;DLNA.ORG_CI=1;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_LRGTN" size="100000">http://192.168.54.1:50001/DS1000184.JPG</res></item><item id="1000189" parentID="0" restricted="0"><dc:title>100-0189</dc:title><upnp:writeStatus>WRITABLE</upnp:writeStatus><upnp:class name="imageItem">object.item.imageItem</upnp:class><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_LRG;DLNA.ORG_OP=01;DLNA.ORG_CI=0;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_ORG" size="4447744">http://192.168.54.1:50001/DO1000189.JPG</res><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_TN;DLNA.ORG_OP=01;DLNA.ORG_CI=1;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_TN" size="5000">http://192.168.54.1:50001/DT1000189.JPG</res><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_SM;DLNA.ORG_OP=01;DLNA.ORG_CI=1;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_LRGTN" size="100000">http://192.168.54.1:50001/DS1000189.JPG</res></item><item id="1000194" parentID="0" restricted="0"><dc:title>100-0194</dc:title><upnp:writeStatus>WRITABLE</upnp:writeStatus><upnp:class name="imageItem">object.item.imageItem</upnp:class><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_LRG;DLNA.ORG_OP=01;DLNA.ORG_CI=0;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_ORG" size="3723776">http://192.168.54.1:50001/DO1000194.JPG</res><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_TN;DLNA.ORG_OP=01;DLNA.ORG_CI=1;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_TN" size="5000">http://192.168.54.1:50001/DT1000194.JPG</res><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_SM;DLNA.ORG_OP=01;DLNA.ORG_CI=1;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_LRGTN" size="100000">http://192.168.54.1:50001/DS1000194.JPG</res></item><item id="1000197" parentID="0" restricted="0"><dc:title>100-0197</dc:title><upnp:writeStatus>WRITABLE</upnp:writeStatus><upnp:class name="imageItem">object.item.imageItem</upnp:class><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_LRG;DLNA.ORG_OP=01;DLNA.ORG_CI=0;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_ORG" size="3742720">http://192.168.54.1:50001/DO1000197.JPG</res><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_TN;DLNA.ORG_OP=01;DLNA.ORG_CI=1;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_TN" size="5000">http://192.168.54.1:50001/DT1000197.JPG</res><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_SM;DLNA.ORG_OP=01;DLNA.ORG_CI=1;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_LRGTN" size="100000">http://192.168.54.1:50001/DS1000197.JPG</res></item><item id="1000201" parentID="0" restricted="0"><dc:title>100-0201</dc:title><upnp:writeStatus>WRITABLE</upnp:writeStatus><upnp:class name="imageItem">object.item.imageItem</upnp:class><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_LRG;DLNA.ORG_OP=01;DLNA.ORG_CI=0;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_ORG" size="3662336">http://192.168.54.1:50001/DO1000201.JPG</res><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_TN;DLNA.ORG_OP=01;DLNA.ORG_CI=1;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_TN" size="5000">http://192.168.54.1:50001/DT1000201.JPG</res><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_SM;DLNA.ORG_OP=01;DLNA.ORG_CI=1;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_LRGTN" size="100000">http://192.168.54.1:50001/DS1000201.JPG</res></item><item id="1000203" parentID="0" restricted="0"><dc:title>100-0203</dc:title><upnp:writeStatus>WRITABLE</upnp:writeStatus><upnp:class name="imageItem">object.item.imageItem</upnp:class><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_LRG;DLNA.ORG_OP=01;DLNA.ORG_CI=0;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_ORG" size="3656192">http://192.168.54.1:50001/DO1000203.JPG</res><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_TN;DLNA.ORG_OP=01;DLNA.ORG_CI=1;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_TN" size="5000">http://192.168.54.1:50001/DT1000203.JPG</res><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_SM;DLNA.ORG_OP=01;DLNA.ORG_CI=1;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_LRGTN" size="100000">http://192.168.54.1:50001/DS1000203.JPG</res></item><item id="1000206" parentID="0" restricted="0"><dc:title>100-0206</dc:title><upnp:writeStatus>WRITABLE</upnp:writeStatus><upnp:class name="imageItem">object.item.imageItem</upnp:class><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_LRG;DLNA.ORG_OP=01;DLNA.ORG_CI=0;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_ORG" size="
000000000000000000000000;PANASONIC.COM_PN=CAM_ORG" duration="0:00:31" size="106285743">http://192.168.54.1:50001/DO1000321.MP4</res><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_TN;DLNA.ORG_OP=01;DLNA.ORG_CI=1;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_TN" size="5000">http://192.168.54.1:50001/DT1000321.JPG</res><res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_SM;DLNA.ORG_OP=01;DLNA.ORG_CI=1;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_LRGTN" size="100000">http://192.168.54.1:50001/DS1000321.JPG</res></item><item id="1000326" parentID="0" restricted="0"><dc:title>100-0326</dc:title><upnp:writeStatus>WRITABLE</upnp:writeStatus><upnp:class name="imageItem">object.item.imageItem</upnp:class><res protocolInfo="http-get:*:application/octet-stream;PANASONIC.COM_PN=UNKNOWN_DATA" size="0">http://192.168.54.1:50001/DO1000326.JPG</res><res protocolInfo="http-get:*:application/octet-stream;PANASONIC.COM_PN=UNKNOWN_DATA" size="5000">http://192.168.54.1:50001/DT1000326.JPG</res><res protocolInfo="http-get:*:application/octet-stream;PANASONIC.COM_PN=UNKNOWN_DATA" size="100000">http://192.168.54.1:50001/DS1000326.JPG</res></item><item id="1000328" parentID="0" restricted="0"><dc:title>100-0328</dc:title><upnp:writeStatus>WRITABLE</upnp:writeStatus><upnp:class name="imageItem">object.item.imageItem</upnp:class><res protocolInfo="http-get:*:application/octet-stream;PANASONIC.COM_PN=UNKNOWN_DATA" size="0">http://192.168.54.1:50001/DO1000328.JPG</res><res protocolInfo="http-get:*:application/octet-stream;PANASONIC.COM_PN=UNKNOWN_DATA" size="5000">http://192.168.54.1:50001/DT1000328.JPG</res><res protocolInfo="http-get:*:application/octet-stream;PANASONIC.COM_PN=UNKNOWN_DATA" size="100000">http://192.168.54.1:50001/DS1000328.JPG</res></item><item id="1000331" parentID="0" restricted="0"><dc:title>100-0331</dc:title><upnp:writeStatus>WRITABLE</upnp:writeStatus><upnp:class name="imageItem">object.item.imageItem</upnp:class><res protocolInfo="http-get:*:application/octet-stream;PANASONIC.COM_PN=UNKNOWN_DATA" size="0">http://192.168.54.1:50001/DO1000331.JPG</res><res protocolInfo="http-get:*:application/octet-stream;PANASONIC.COM_PN=UNKNOWN_DATA" size="5000">http://192.168.54.1:50001/DT1000331.JPG</res><res protocolInfo="http-get:*:application/octet-stream;PANASONIC.COM_PN=UNKNOWN_DATA" size="100000">http://192.168.54.1:50001/DS1000331.JPG</res></item><item id="1000336" parentID="0" restricted="0"><dc:title>100-0336</dc:title><upnp:writeStatus>WRITABLE</upnp:writeStatus><upnp:class name="imageItem">object.item.imageItem</upnp:class><res protocolInfo="http-get:*:application/octet-stream;PANASONIC.COM_PN=UNKNOWN_DATA" size="0">http://192.168.54.1:50001/DO1000336.JPG</res><res protocolInfo="http-get:*:application/octet-stream;PANASONIC.COM_PN=UNKNOWN_DATA" size="5000">http://192.168.54.1:50001/DT1000336.JPG</res><res protocolInfo="http-get:*:application/octet-stream;PANASONIC.COM_PN=UNKNOWN_DATA" size="100000">http://192.168.54.1:50001/DS1000336.JPG</res></item><item id="1000354" parentID="0" restricted="0"><dc:title>100-0354</dc:title><upnp:writeStatus>WRITABLE</upnp:writeStatus><upnp:class name="imageItem">object.item.imageItem</upnp:class><res protocolInfo="http-get:*:application/octet-stream;PANASONIC.COM_PN=UNKNOWN_DATA" size="0">http://192.168.54.1:50001/DO1000354.JPG</res><res protocolInfo="http-get:*:application/octet-stream;PANASONIC.COM_PN=UNKNOWN_DATA" size="5000">http://192.168.54.1:50001/DT1000354.JPG</res><res protocolInfo="http-get:*:application/octet-stream;PANASONIC.COM_PN=UNKNOWN_DATA" size="100000">http://192.168.54.1:50001/DS1000354.JPG</res></item><item id="1000359" parentID="0" restricted="0"><dc:title>100-0359</dc:title><upnp:writeStatus>WRITABLE</upnp:writeStatus><upnp:class name="imageItem">object.item.imageItem</upnp:class><res protocolInfo="http-get:*:application/octet-stream;PANASONIC.COM_PN=UNKNOWN_DATA" size="0">http://192.168.54.1:50001/DO1000359.JPG</res><res protocolInfo="http-get:*:application/octet-stream;PANASONIC.COM_PN=UNKNOWN_DATA" size="5000">http://192.168.54.1:50001/DT1000359.JPG</res><res protocolInfo="http-get:*:application/octet-stream;PANASONIC.COM_PN=UNKNOWN_DATA" size="100000">http://192.168.54.1:50001/DS1000359.JPG</res></item><item id="1000366" parentID="0" restricted="0"><dc:title>100-0366</dc:title><upnp:writeStatus>WRITABLE</upnp:writeStatus><upnp:class name="imageItem">object.item.imageItem</upnp:class><res protocolInfo="http-get:*:application/octet-stream;PANASONIC.COM_PN=UNKNOWN_DATA" size="0">http://192.168.54.1:50001/DO1000366.JPG</res><res protocolInfo="http-get:*:application/octet-stream;PANASONIC.COM_PN=UNKNOWN_DATA" size="5000">http://192.168.54.1:50001/DT1000366.JPG</res><res protocolInfo="http-get:*:application/octet-stream;PANASONIC.COM_PN=UNKNOWN_DATA" size="100000">http://192.168.54.1:50001/DS1000366.JPG</res></item><item id="1000379" parentID="0" restricted="0"><dc:title>100-0379</dc:title><upnp:writeStatus>WRITABLE</upnp:writeStatus><upnp:class name="imageItem">object.item.imageItem</upnp:class><res protocolInfo="http-get:*:application/octet-stream;PANASONIC.COM_PN=UNKNOWN_DATA" size="0">http://192.168.54.1:50001/DO1000379.JPG</res><res protocolInfo="http-get:*:application/octet-stream;PANASONIC.COM_PN=UNKNOWN_DATA" size="5000">http://192.168.54.1:50001/DT1000379.JPG</res><res protocolInfo="http-get:*:application/octet-stream;PANASONIC.COM_PN=UNKNOWN_DATA" size="100000">http://192.168.54.1:50001/DS1000379.JPG</res></item><item id="1000385" parentID="0" restricted="0"><dc:title>100-0385</dc:title><upnp:writeStatus>WRITABLE</upnp:writeStatus><upnp:class name="imageItem">object.item.imageItem</upnp:class><res protocolInfo="http-get:*:application/octet-stream;PANASONIC.COM_PN=UNKNOWN_DATA" size="0">http://192.168.54.1:50001/DO1000385.JPG</res><res protocolInfo="http-get:*:application/octet-stream;PANASONIC.COM_PN=UNKNOWN_DATA" size="5000">http://192.168.54.1:50001/DT1000385.JPG</res><res protocolInfo="http-get:*:application/octet-stream;PANASONIC.COM_PN=UNKNOWN_DATA" size="100000">http://192.168.54.1:50001/DS1000385.JPG</res></item><item id="1000404" parentID="0" restricted="0"><dc:title>100-0404</dc:title><upnp:writeStatus>WRITABLE</upnp:writeStatus><upnp:class name="imageItem">object.item.imageItem</upnp:class><res protocolInfo="http-get:*:application/octet-stream;PANASONIC.COM_PN=UNKNOWN_DATA" size="0">http://192.168.54.1:50001/DO1000404.JPG</res><res protocolInfo="http-get:*:application/octet-stream;PANASONIC.COM_PN=UNKNOWN_DATA" size="5000">http://192.168.54.1:50001/DT1000404.JPG</res><res protocolInfo="http-get:*:application/octet-stream;PANASONIC.COM_PN=UNKNOWN_DATA" size="100000">http://192.168.54.1:50001/DS1000404.JPG</res></item></DIDL-Lite>'

# %%
root = ET.fromstring(a)
ET.indent(root)
ET.dump(root)
# Out:
# <ns0:DIDL-Lite xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:ns0="urn:schemas-upnp-org:metadata-1-0/DIDL-Lite/" xmlns:ns2="urn:schemas-upnp-org:metadata-1-0/upnp/">
#   <ns0:item id="1000092" parentID="0" restricted="0">
#     <dc:title>100-0092</dc:title>
#     <ns2:writeStatus>WRITABLE</ns2:writeStatus>
#     <ns2:class name="imageItem">object.item.imageItem</ns2:class>
#     <ns0:res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_LRG;DLNA.ORG_OP=01;DLNA.ORG_CI=0;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_ORG" size="3284480">http://192.168.54.1:50001/DO1000092.JPG</ns0:res>
#     <ns0:res protocolInfo="http-get:*:image/jpeg:DLNA.ORG_PN=JPEG_TN;DLNA.ORG_OP=01;DLNA.ORG_CI=1;DLNA.ORG_FLAGS=00900000000000000000000000000000;PANASONIC.COM_PN=CAM_TN" size="5000">http://192.168.54.1:50001/DT1000092.JPG</ns0:res>
# ...

# %%
b = a
root = ET.fromstring(b)
data = []
for element in root:
    picture = {}
    picture["title"] = element.find("{http://purl.org/dc/elements/1.1/}title").text
    sizes = ["original","thumbnail","medium"]
    for ptype, info in zip(sizes, element.findall("{urn:schemas-upnp-org:metadata-1-0/DIDL-Lite/}res")):
        picture[ptype] = {"size" : info.attrib["size"], "name": info.text.split("/")[-1]}
    data.append(picture)
data
len(data)
# Out:
# 50

# %%
var = {}
var["SOT".index("O")] = "oK"
var
# Out:
# {1: 'oK'}

# %%
min(1,4)
# Out:
# 1
